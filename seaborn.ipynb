# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.get_dataset_names() # seaborn consists these datasets in it
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset("tips")  # from seaborn we use 'tips' dataset
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head(6)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.shape # returns no.of rows and cols
# Out:
# (244, 7)

# %%
h=df['size'].dtype # datatype of size column in dataframe
h
df.dtypes # overall datatypes of columns in dataframe
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.describe() # this describe only float,int like numeric values describe only
#df.describe(include='category') # category data type columns  only describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#df['total_bill'].max() # tip column max value
#df['total_bill'].min() # size column min value
df['tip'].mean()
# Out:
# np.float64(2.99827868852459)

# %% [raw]
# insights of describe():
#            Most customers are Male
#            Most are Non-smokers
#            Saturday is the busiest day
#            Dinner time has the highest visits
#            Maximum tip is 10

# %% [raw]
# Insights for size column :
#
# Represents number of people per table
#
# Minimum size = 1, maximum size = 6
#
# Average size = 2.6
#
# Most common group size = 2
#
# Majority tables have 2–3 people

# %% [raw]
# insights of total_bill():-
#  this tells the total amount of the restaurant bill
#  avg bill=19.78594262295082
#  range of bill= 3.07 to 50.81
#  common bill values= 13.3 - 24.1
#  50% bill values= 17.7
#
# insights of tip():-
#    this column represents tip given in restaurant
#    mean value =2.9

# %% [raw]
# # null value treatment and imputation
# A.Fill the missing records:
#   1.mean median mode
#       object data type--> mode
#   2.domain
# B.Remove the missing data:
#   1.remove the rows in which missing position
#      -->dropna -->>all row or particular record  of that particular row is deleted
#       after dropna method droping data if loss is less than 20 we use this row removing
#       lossed data by removing ==(no.of records removed/total no.of records) *100
#       present data after removing =(remaining records after removing/total no.of records) *100
#       formula = ((df.shape[0]-df.dropna().shape[0])/df.shape[0])*100
#   2.remove the columns in which missing position
#       loss value>20 after calculating --> remove that column
#       formula=(df.isna().sum()/df.shape[0])*100

# %%
# null value treatment and imputation
#df.isnull().sum()
#df.isna().sum()
percentage_of_missing_data=(df.isna().sum()/df.shape[0])*100 # formula for loss calculation of missing data for column removing
percentage_of_missing_data
# Out:
# total_bill    0.0
# tip           0.0
# sex           0.0
# smoker        0.0
# day           0.0
# time          0.0
# size          0.0
# dtype: float64

# %% [raw]
# TITANIC DATASET

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
df.shape
df.dtypes
#df.describe()
#df.describe(include='bool')
#df.describe(include='category')
#df.describe(include='object')
#df.columns
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
((df.shape[0]-df.dropna().shape[0])/df.shape[0])*100 # row removing if <20 but it is greater
# Out:
# 79.57351290684625

# %%
percentage_of_missing_data=(df.isna().sum()/df.shape[0])*100 #checking for column removing 
percentage_of_missing_data
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
k=df.dropna() #remove null value records temporarily
k.shape # no.of rows and cols after removing null value records
# Out:
# (182, 15)

# %%
df.drop('deck', axis=1, inplace=True) # to drop 'deck' col from dataset as it is >20 of loss
df.columns # check the col is dropped or not
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
df['age'] = df['age'].fillna(df['age'].median())
df['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df['embarked'] = df['embarked'].fillna(df['embarked'].mode()[0])# fill the missing values in embarked with mode
df['embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: embarked, Length: 891, dtype: object

# %%
df['embark_town']= df['embark_town'].fillna(df['embark_town'].mode()[0]) # fill the missing values in embark_town with mode
df['embark_town']
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: embark_town, Length: 891, dtype: object

# %%
df.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df.info()
# numerical cols--->  survived,pclass,age,sibsp,parch,fare---> histplot
# categorical cols---> remaining all are categorical only---->countplot
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  891 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %% [raw]
# | Data Type                  | Best Plot            |
# | -------------------------- | -------------------- |
# | Categorical vs Numerical   | boxplot, violinplot  |
# | Single  Categorical        | countplot            |
# | Numerical vs Numerical     | scatterplot          |
# | Single Numerical           | histplot, kdeplot    |
# | Categorical vs Categorical | countplot (with hue) |
# | Numerical vs Categorical   | histplot             |
# univariate analysis :-
#      numerical data-->histplot ,kdeplot
#      categorical data--> countplot
# bivariate analysis :-
#      two combinations of data (N vs N,C vs C, N vs C, C vs N)
#      hue must be categorical column

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'],kde=True) # kde is for curve
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alone'])
plt.show()

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'], hue=df['sex'],kde=True) # numerical vs categorical and hue must be categoricalcolumn
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'], hue=df['sex']) # numerical vs categorical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'], hue=df['sex'],kde=True) # numerical vs categorical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'], hue=df['sex'],kde=True) # numerical vs categorical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'], hue=df['sex'],kde=True) # numerical vs categorical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'], hue=df['sex'],kde=True) # numerical vs categorical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'], hue=df['sex'],kde=True) # numerical vs categorical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'], hue=df['class'],kde=True) # numerical vs categorical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['sex'], hue=df['alone']) # categorical vs categorical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['embark_town'], hue=df['alive']) # categorical vs categorical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['who'], hue=df['alive']) # categorical vs categorical
plt.show()

# %% [raw]
# #bivariate
# SCATTERPLOT
# syntax:-
#     plt.figure(figsize=(5,5))
#     sns.scatterplot(x='numerical',y='numerical') # only numerical cols
#     plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['pclass'], y=df['fare']) # numerical vs numerical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['pclass'], y=df['parch']) # numerical vs numerical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'], y=df['pclass']) # numerical vs numerical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'], y=df['sibsp']) # numerical vs numerical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['fare'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'], y=df['sibsp']) # numerical vs numerical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'], y=df['parch']) # numerical vs numerical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'], y=df['fare']) # numerical vs numerical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'], y=df['pclass']) # numerical vs numerical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['sibsp'], y=df['parch']) # numerical vs numerical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['sibsp'], y=df['fare']) # numerical vs numerical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['sibsp'], y=df['pclass']) # numerical vs numerical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['parch'], y=df['fare']) # numerical vs numerical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['parch'], y=df['pclass']) # numerical vs numerical
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['fare'], y=df['pclass']) # numerical vs numerical
plt.show()

# %% [raw]
# # SCATTERPLOT WITH MULTIVARIATES
#    X,Y must be numeric and hue must be categorical only

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'], y=df['age'],hue=df['sex']) # numerical,numerical and categorical comparision only(x,y-->must be numeric ,hue-->must be categorical only)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'], y=df['age'],hue=df['embarked']) # numerical,numerical and categorical comparision only(x,y-->must be numeric ,hue-->must be categorical only)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'], y=df['age'],hue=df['class']) # numerical,numerical and categorical comparision only(x,y-->must be numeric ,hue-->must be categorical only)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'], y=df['age'],hue=df['who']) # numerical,numerical and categorical comparision only(x,y-->must be numeric ,hue-->must be categorical only)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'], y=df['age'],hue=df['adult_male']) # numerical,numerical and categorical comparision only(x,y-->must be numeric ,hue-->must be categorical only)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'], y=df['age'],hue=df['embark_town']) # numerical,numerical and categorical comparision only(x,y-->must be numeric ,hue-->must be categorical only)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'], y=df['age'],hue=df['alive']) # numerical,numerical and categorical comparision only(x,y-->must be numeric ,hue-->must be categorical only)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['sibsp'] ,hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['sibsp'] ,hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['sibsp'] ,hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['sibsp'] ,hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['sibsp'] ,hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['sibsp'] ,hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['sibsp'] ,hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['parch'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['parch'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['parch'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['parch'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['parch'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['parch'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['parch'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['fare'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['fare'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['fare'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['fare'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['fare'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['fare'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['fare'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['pclass'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['pclass'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['pclass'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['pclass'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['pclass'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['pclass'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['survived'],y=df['pclass'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['sibsp'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['sibsp'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['sibsp'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['sibsp'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['sibsp'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['sibsp'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['sibsp'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['parch'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['parch'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['parch'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['parch'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['parch'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['parch'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['parch'],hue=df['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['fare'],hue=df['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['fare'],hue=df['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['fare'],hue=df['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['fare'],hue=df['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['fare'],hue=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['fare'],hue=df['embark_town'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df['age'],y=df['fare'],hue=df['alive'])
plt.show()

# %% [raw]
# #bivariate
# BARPLOT:-
#  plt.figure(figsize=(5,5))
#  sns.barplot(x=df[''],y=df[''],estimator='mean')  # one should be numeric and other should be categorical like (N vs C) or (C vs N)
#  plt.show()                        # estimator is optional

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['survived'],y=df['alone']) # numerical vs categorical plot 
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['class'],y=df['alone'],estimator='mean')  # categorical vs numerical plot as per the estimator
 plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sex'],y=df['age'],estimator='std')  # categorical vs numerical plot as per the estimator
plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['survived'],y=df['sex']) # numerical vs categorical plot  
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['survived'],y=df['embarked']) # numerical vs categorical plot  
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['survived'],y=df['class']) # numerical vs categorical plot 
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['survived'],y=df['who']) # numerical vs categorical plot  
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['survived'],y=df['adult_male']) # numerical vs categorical plot  
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['survived'],y=df['embark_town']) # numerical vs categorical plot 
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['survived'],y=df['alive']) # numerical vs categorical plot  
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['parch'],y=df['alone']) # numerical vs categorical plot
# Out:
# <Axes: xlabel='parch', ylabel='alone'>

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['fare'],y=df['alone']) # numerical vs categorical plot 
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['age'],y=df['alone']) # numerical vs categorical plot 
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['pclass'],y=df['alone']) # numerical vs categorical plot  
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['sibsp'],y=df['alone']) # numerical vs categorical  
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['age'],y=df['alive']) # numerical vs categorical 
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['pclass'],y=df['alive']) # numerical vs categorical plot 
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['pclass'],y=df['embarked']) # numerical vs categorical plot 
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['pclass'],y=df['embark_town']) # numerical vs categorical plot  
 plt.show()

# %% [raw]
# BARplot with multivariate
# x,y can be numeric and categorical or categorical and numeric but hue must be categorical only

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['pclass'],y=df['embark_town'],hue=df['class'],dodge=True) # dodge is use to  determines whether plot elements for different hue levels are drawn side-by-side (True) or overlapping (False).  
 plt.show()

# %%
 plt.figure(figsize=(5,5))
 sns.barplot(x=df['pclass'],y=df['embark_town'],hue=df['class'],dodge=False) # dodge is use to  determines whether plot elements for different hue levels are drawn side-by-side (True) or overlapping (False).  
 plt.show()

# %% [raw]
# UNIVARIATE ANALYSIS
# sns.boxplot(x=numerical)  # to identify outliers and one should be numerical and other should be categorical ifbivariate used
# plt.show()
# lb=q1-1.5iqr
# ub=q3+1.5iqr
#
# OUTLIERS:- data that deviated from original data
#  1.ERROR
#  2.natural variation

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['pclass']) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['survived']) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['age']) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['fare']) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['sibsp']) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['parch']) 
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  891 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['sex'],y=df['survived'] ) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['embarked'],y=df['survived'] ) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['class'],y=df['survived'] ) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['survived'],y=df['who'] ) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['survived'],y=df['adult_male'] ) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['embark_town'],y=df['survived'] ) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['survived'],y=df['alive'] ) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['survived'],y=df['alone'] ) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['pclass'],y=df['sex'] ) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['pclass'],y=df['embarked'] ) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['pclass'],y=df['class'] ) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['pclass'],y=df['who'] ) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['pclass'],y=df['adult_male'] ) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['pclass'],y=df['embark_town'] ) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['pclass'],y=df['alive'] ) 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['pclass'],y=df['alone'] ) 
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')  # to avoid warnings  during plotting we use this  and warnings are not errors

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['pclass'],y=df['alive'], palette='Pastel1') # palette is for coloring 
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['pclass'],y=df['alive'], palette='Set2') # palette is for coloring and capital S
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['pclass'],y=df['alive'], palette='viridis') # palette is for coloring and small v
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['pclass'],y=df['alive'], palette='coolwarm')  # palette is for coloring
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['embarked'],y=df['survived'],palette='Pastel1')  #Pastel1  --> p capital
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df['embarked'],y=df['survived'],palette='coolwarm')  # coolwarm --> c small if u give C then error will come
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.stripplot(x=df['embarked'],y=df['sex']) #stripplot(double pp) for categorical values only
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.swarmplot(x=df['embarked'],y=df['sex']) #swarm plot for categorical values only
plt.show()
